# %%
import pandas as pd

# %%
# Reading in prevention data
prevent_df = pd.read_csv('preventativedata.csv')

# Removing unecessary columns
prevent_df = prevent_df.drop(columns=['Data_Value_Unit', 'Data_Value_Footnote_Symbol', 'Data_Value_Footnote', 'TractFIPS', 'CategoryID', 'StateDesc'])
# Out:
#    Year StateAbbr  CityName GeographicLevel DataSource    Category  UniqueID  \
# 0  2016        WA    Yakima            City      BRFSS  Prevention   5380010
# 1  2016        AZ  Avondale            City      BRFSS  Prevention    404720
#
#                                              Measure DataValueTypeID  \
# 0  Older adult men aged >=65 Years who are up to ...          CrdPrv
# 1  Older adult women aged >=65 Years who are up t...          CrdPrv
#
#     Data_Value_Type  Data_Value  Low_Confidence_Limit  High_Confidence_Limit  \
# 0  Crude prevalence        31.3                  29.6                   33.0
# 1  Crude prevalence        27.5                  26.6                   28.3
#
#   PopulationCount                      GeoLocation MeasureId  CityFIPS  \
# 0          91,067  (46.5925792092, -120.547807614)     COREM   5380010
# 1          76,238  (33.3858367405, -112.323626619)     COREW    404720
#
#                         Short_Question_Text
# ...

# %%
prevent_df.columns
# Out:
# Index(['Year', 'StateAbbr', 'CityName', 'GeographicLevel', 'DataSource',
#        'Category', 'UniqueID', 'Measure', 'DataValueTypeID', 'Data_Value_Type',
#        'Data_Value', 'Low_Confidence_Limit', 'High_Confidence_Limit',
#        'PopulationCount', 'GeoLocation', 'MeasureId', 'CityFIPS',
#        'Short_Question_Text'],
#       dtype='object')

# %%
prevent_df.head(2)
# Out:
#    Year StateAbbr  CityName GeographicLevel DataSource    Category  UniqueID  \
# 0  2016        WA    Yakima            City      BRFSS  Prevention   5380010
# 1  2016        AZ  Avondale            City      BRFSS  Prevention    404720
#
#                                              Measure DataValueTypeID  \
# 0  Older adult men aged >=65 Years who are up to ...          CrdPrv
# 1  Older adult women aged >=65 Years who are up t...          CrdPrv
#
#     Data_Value_Type  Data_Value  Low_Confidence_Limit  High_Confidence_Limit  \
# 0  Crude prevalence        31.3                  29.6                   33.0
# 1  Crude prevalence        27.5                  26.6                   28.3
#
#   PopulationCount                      GeoLocation MeasureId  CityFIPS  \
# 0          91,067  (46.5925792092, -120.547807614)     COREM   5380010
# 1          76,238  (33.3858367405, -112.323626619)     COREW    404720
#
#                         Short_Question_Text
# ...

# %%
# Sorting values by unique ID
prevent_df.sort_values(by=['UniqueID'], ascending=True).reset_index()
# Out:
#      index  Year StateAbbr    CityName GeographicLevel DataSource    Category  \
# 0      412  2016        HI    Honolulu            City      BRFSS  Prevention
# 1      423  2016        HI    Honolulu            City      BRFSS  Prevention
# 2      131  2016        AL  Birmingham            City      BRFSS  Prevention
# 3      133  2016        AL  Birmingham            City      BRFSS  Prevention
# 4      135  2016        AL      Hoover            City      BRFSS  Prevention
# ..     ...   ...       ...         ...             ...        ...         ...
# 995    999  2016        WI      Racine            City      BRFSS  Prevention
# 996    995  2016        WI    Waukesha            City      BRFSS  Prevention
# 997    997  2016        WI    Waukesha            City      BRFSS  Prevention
# 998    998  2016        WY    Cheyenne            City      BRFSS  Prevention
# 999    994  2016        WY    Cheyenne            City      BRFSS  Prevention
#
# ...
